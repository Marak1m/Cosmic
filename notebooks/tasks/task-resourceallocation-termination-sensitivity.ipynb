# %%
import sys
from pathlib import Path

# Ensure repo root is on sys.path so `from tools...` imports work from any notebook subfolder.
_p = Path.cwd().resolve()
for _parent in [_p, *_p.parents]:
    if (_parent / 'tools' / 'search_tools.py').exists():
        sys.path.insert(0, str(_parent))
        break
del _p, _parent

# %% [markdown]
# # COSMIC: Termination Hyperparameter Sensitivity (Resource Allocation)
#
# This notebook runs a small sensitivity sweep over termination-related hyperparameters and writes `termination_sensitivity.csv`.
#
# It uses the runnable sweep harness in `scripts/termination_sensitivity_sweep.py`.

# %%
import os

if not os.getenv("OPENAI_API_KEY"):
    raise RuntimeError(
        "OPENAI_API_KEY is not set. Set it in your environment (do not commit keys) and re-run."
    )

print("OPENAI_API_KEY is set (value not shown).")

# %%
import scripts.termination_sensitivity_sweep as sweep

# Minimum is 3. If you can afford it, set to 5.
sweep.K_RUNS = 3

df = sweep.run_sweep()
df

# %%
import pandas as pd

df2 = pd.read_csv("termination_sensitivity.csv")
df2
